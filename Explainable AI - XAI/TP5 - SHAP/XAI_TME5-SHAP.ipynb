# %% [markdown]
# # Qui êtes-vous ?
# <div class="alert alert-block alert-info">
# Écrire ci-dessous votre nom, prénom et numéro étudiant :
# </div>

# %%
# NOM Prénom NuméroEtud

# %% [markdown]
# # TME 5- SHAP

# %% [markdown]
# <div class="alert alert-block alert-warning">
# L'objet de ce TME est de tester l'algorithme SHAP sur des tâches de classification assez simples et de le comparer avec LIME (voire avec les explications contrefactuelles si vous ne l'avez pas fait dans les TME précédents).
# </div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1 - Préparation du dataset
#
#
# <div class="alert alert-block alert-warning">
# Utiliser par exemple le dataset <a href="https://archive.ics.uci.edu/ml/datasets/Breast+Cancer+Wisconsin+(Diagnostic)">UCI ML Breast Cancer Wisconsin (Diagnostic)</a>, et apprendre par exemple un modèle linéaire de régression logistique
# </div>

# %% [markdown]
# ## 2- Explication avec SHAP
#
# <div class="alert alert-block alert-warning">
# Cette section donne deux exemples d'utilisation de SHAP, de nombreux autres sont possibles.
# </div>

# %% [markdown]
# <div class = "alert alert-block alert-info">
#     Q2.1 - Exécuter le bloc ci-dessous pour obtenir les explications globales de SHAP. Commentez.
# </div>

# %%
import shap

explainer = shap.KernelExplainer(logreg, X_train)
shap_values = explainer.shap_values(X_test)

shap.summary_plot(shap_values, X_test, plot_type="bar", feature_names=feature_names)

# %%
# Commentaire :

# %% [markdown]
# <div class = "alert alert-block alert-info">
#     Q2.2 - Exécuter le bloc ci-dessous pour obtenir une explication locale avec SHAP du premier exemple de la base de test. Commentez.
# </div>

# %%
shap.initjs()
shap.force_plot(
    explainer.expected_value,
    shap_values[0, :],
    X_test[0, :],
    feature_names=feature_names,
)

# %%
# Commentaire

# %% [markdown]
# <div class = "alert alert-block alert-info">
#     Q2.3 - Comparer avec l'exemple suivant de la base de test.
# </div>

# %% [markdown]
# ## 3 - Expérimentations
#
# <div class="alert alert-block alert-warning">
#     Comme lors des autres TME, l'objectif est de mener des expérimentations pour tester différentes propriétés des explications générées par SHAP, en elles-mêmes ou en comparaison avec d'autres explications :
#     <ul>
#         <li> Etudier les paramètres qui influencent le plus le temps de calcul de kernelSHAP (nombre de données, nombre d'attributs, ...)</li>
#         <li> Pour un classifieur de type arbre, tester TreeSHAP (Explainer ou TreeExplainer), comparer à kernalSHAP</li>
#         <li> Etudier la robustesse des explications fournies par SHAP, lors d'utilisations répétées dans une même configuration</li>
#         <li> Etudier les explications fournies pour une même donnée et des classifieurs différents</li>
#         <li> Comparer les résultats fournis par LIME et SHAP sur des données identiques et commenter les résultats</li>
#     <li> Examiner les résultats par exemple sur les données half-moons dans un cas où une explication linéaire est inappropriée</li>
#     <li> Modifier votre propre implémentation de LIME pour utiliser le noyau SHAP et comparer au résultat fourni par SHAP</li>
#         <li> ... </li>
#         </ul>
# </div>

# %% [markdown]
# ## 4 - Données textuelles
#
# <div class="alert alert-block alert-warning">
#     Apprendre un modèle de classification random forest sur les données <code>fetch_20newsgroups</code> puis utiliser LIME et SHAP pour obtenir des explications sur la classification d'exemples.
# </div>

# %% [markdown]
# <div class = "alert alert-block alert-info">
# À l'aide de la <a href="https://scikit-learn.org/stable/auto_examples/text/plot_document_classification_20newsgroups.html#sphx-glr-auto-examples-text-plot-document-classification-20newsgroups-py">documentation du dataset fetch_20newsgroups</a>,  apprendre un modèle random forest de classification bi-classe de texte.
# </div>

# %% [markdown]
# <div class = "alert alert-block alert-info">
# Utilisez LIME et SHAP pour obtenir des explications sur les prédictions obtenues sur des exemples.
#     </div>
